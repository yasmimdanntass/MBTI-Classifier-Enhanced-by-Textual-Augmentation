# %%
# !pip3 install pandas
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
#      |████████████████████████████████| 10.8 MB 1.5 MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 349 kB 34.1 MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 5.3 MB 45.8 MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 510 kB 52.7 MB/s eta 0:00:01
# ...
# WARNING: You are using pip version 21.2.4; however, version 26.0.1 is available.
# You should consider upgrading via the '/Library/Developer/CommandLineTools/usr/bin/python3 -m pip install --upgrade pip' command.

# %%
import pandas as pd 
from pipeline.preprocessor import Preprocessor
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 import pandas as pd
#       2 from pipeline.preprocessor import Preprocessor
#
# ModuleNotFoundError: No module named 'pandas'

# %%
preprocessor = Preprocessor('body')

# %%
df = pd.read_csv('data/MBTI_5M_version_unclean.csv')
# Out:
# /var/folders/by/fx0cy12x2h3dvj961c5y3cxm0000gn/T/ipykernel_5554/3492637699.py:1: DtypeWarning: Columns (1,2) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('data/MBTI_5M_version_unclean.csv')

# %%
df.head()
# Out:
#    Unnamed: 0                                               body  mbti
# 0           0  Knowing you're in INTJ is a tool for you to us...  INTJ
# 1           1           You are truly an enlightened mastermind.  INTJ
# 2           2  You should :) it will help if you have a down ...  INFJ
# 3           3  I watch a bit of everything (including hentai)...  INTP
# 4           4  I don't know if I would count this as a pet pe...  INTJ

# %%
df = df.dropna()

# %%
df.drop(columns = ['Unnamed: 0'], inplace = True)

# %%
preprocessor = Preprocessor('body')

# %%
df_clean = preprocessor.preprocess_simple(df)

# %%
df.head()
# Out:
#                                                 body  mbti
# 0  knowing youre in intj is a tool for you to use...  INTJ
# 1            you are truly an enlightened mastermind  INTJ
# 2  you should it will help if you have a down mom...  INFJ
# 3  i watch a bit of everything including hentai i...  INTP
# 4  i dont know if i would count this as a pet pee...  INTJ

# %%
df.to_csv('data/clean_datasets/light_cleaning_MBTI_5M.csv')

# %%
import gc

gc.collect()
# Out:
# 0

# %%
df = pd.read_csv('data/MBTI_5M_version_unclean.csv')
# Out:
# /var/folders/by/fx0cy12x2h3dvj961c5y3cxm0000gn/T/ipykernel_5346/3492637699.py:1: DtypeWarning: Columns (1,2) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('data/MBTI_5M_version_unclean.csv')

# %%
df = df.dropna()

# %%
import nltk

nltk.download('wordnet')
# Out:
# [nltk_data] Downloading package wordnet to
# [nltk_data]     /Users/yasmimdantas/nltk_data...
# True

# %%
df_clean = preprocessor.preprocess_complete(df)

# %%
df_clean.head()
# Out:
#                                                 body  mbti
# 0  knowing youre in intj is a tool for you to use...  INTJ
# 1            you are truly an enlightened mastermind  INTJ
# 2  you should happyfaceorsmiley it will help if y...  INFJ
# 3  i watch a bit of everything including hentai i...  INTP
# 4  i dont know if i would count this a a pet peez...  INTJ

# %%
df['body'] = df['body'].apply(remove_stopwords)

# %%
df_clean['body'] = df_clean['body'].apply(lambda x: x.lower())

# %%
df_clean.head()
# Out:
#                                                 body  mbti
# 0  knowing youre intj tool use interaction people...  INTJ
# 1                       truly enlightened mastermind  INTJ
# 2  happyfaceorsmiley help moment hobby keep mind ...  INFJ
# 3  watch bit everything including hentai tend enj...  INTP
# 4  dont know would count pet peeze something time...  INTJ

# %%
df_clean.to_csv('data/clean_datasets/deep_cleaning_MBTI_5M.csv')

# %%
df_clean.head()
# Out:
#                                                 body  mbti
# 0  knowing youre intj tool use interaction people...  INTJ
# 1                       truly enlightened mastermind  INTJ
# 2  happyfaceorsmiley help moment hobby keep mind ...  INFJ
# 3  watch bit everything including hentai tend enj...  INTP
# 4  dont know would count pet peeze something time...  INTJ
